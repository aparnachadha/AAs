# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnachadha/AAs/blob/main/Copy_of_ADV_C195_4(Solution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Additional-Activity-4
#plot the pie chart showing the percentage of firespots in a state

#predefine code start
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv('https://shravantihable.github.io/AA/inpe_brazilian_amazon_fires_1999_2019.csv')
df
#predefine code ends

#apply the groupby function on 'state' column and add another column  'firespots' , on it apply the max() function to find maximum firespots in a month and reset the index to 0 and store it in variable group_by_state .
group_by_state = df.groupby('state')['firespots'].max().reset_index()
#print the variable group_by_state
group_by_state

#define a variable value and store in it 'firespots' of group_by_state
value = group_by_state['firespots']
#define a variable label and store in it 'state' of group_by_state
label = group_by_state['state']
#use the plt.pie() function, and set the following parameters
#value 
#labels
#autopct- set the percentage upto 1 decimal places
#radius - set the radius of the pie.
plt.pie(value,labels=label, autopct='%0.1f%%', radius=2)
plt.show()
